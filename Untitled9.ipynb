# %%
# import pandas as pd
# import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
import matplotlib.pyplot as plt
import plotly_express as px

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("retail_locations.csv")

# %%
df.head()
# Out:
#    erp_id province_code        lat       long     sales
# 0       4            QC  45.537593 -73.597075  0.089069
# 1      19            QC  45.488636 -73.568175  0.074907
# 2      22            QC  48.387871 -68.470686  0.611644
# 3      24            QC  46.795660 -71.356166 -0.778827
# 4      37            QC  45.510311 -73.570841  0.586588

# %%
locator = Nominatim(user_agent="myGeocoder", timeout=10)
rgeocode = RateLimiter(locator.reverse, min_delay_seconds=0.001)

# %%
df["geom"] = df["lat"].map(str) + "," + df["long"].map(str)
df["geom"]
# Out:
# 0                 45.537593,-73.597075
# 1                 45.488636,-73.568175
# 2               48.3878711,-68.4706861
# 3               46.7956598,-71.3561663
# 4        45.510310700000005,-73.570841
#                      ...
# 1147    46.760380700000006,-71.3637401
# 1148            46.8177823,-71.2532137
# 1149            45.7574496,-73.4799655
# 1150            46.8166991,-71.2025507
# 1151            45.4955477,-73.4739456
# Name: geom, Length: 1152, dtype: object

# %%
df

# %%
a = 2

# %%
a
# Out:
# 2

# %%
def square(number):
    x = number**2
    y = number ** 3
    return x, y

# %%
df = pd.DataFrame(np.random.randint(10, 50, (6,4)))

# %%
df["9"] = df[3].apply(square)

# %%
df
# Out:
#     0   1   2   3  (5, 6)              5              6      8              9
# 0  47  25  46  43    1849  (1849, 79507)  (1849, 79507)  79507  (1849, 79507)
# 1  37  39  16  46    2116  (2116, 97336)  (2116, 97336)  97336  (2116, 97336)
# 2  44  28  31  19     361    (361, 6859)    (361, 6859)   6859    (361, 6859)
# 3  34  32  11  19     361    (361, 6859)    (361, 6859)   6859    (361, 6859)
# 4  40  17  18  22     484   (484, 10648)   (484, 10648)  10648   (484, 10648)
# 5  22  39  34  46    2116  (2116, 97336)  (2116, 97336)  97336  (2116, 97336)

# %%
df["5"][0][1]
# Out:
# 79507

# %%
import pandas as pd
import geopandas as gpd
import plotly_express as px
import matplotlib.pyplot as plt

# %%
df
# Out:
#       erp_id province_code        lat       long     sales  \
# 0          4            QC  45.537593 -73.597075  0.089069
# 1         19            QC  45.488636 -73.568175  0.074907
# 2         22            QC  48.387871 -68.470686  0.611644
# 3         24            QC  46.795660 -71.356166 -0.778827
# 4         37            QC  45.510311 -73.570841  0.586588
# ...      ...           ...        ...        ...       ...
# 1147    6821            QC  46.760381 -71.363740  4.703588
# 1148    6826            QC  46.817782 -71.253214  1.011329
# 1149    6830            QC  45.757450 -73.479966 -1.599532
# 1150    6849            QC  46.816699 -71.202551  0.173749
# 1151    6855            QC  45.495548 -73.473946  0.198582
#
#                                 geom
# 0               45.537593,-73.597075
# 1               45.488636,-73.568175
# 2             48.3878711,-68.4706861
# 3             46.7956598,-71.3561663
# 4      45.510310700000005,-73.570841
# ...

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.long, df.lat))
gdf.head()
# Out:
#    erp_id province_code        lat       long     sales  \
# 0       4            QC  45.537593 -73.597075  0.089069
# 1      19            QC  45.488636 -73.568175  0.074907
# 2      22            QC  48.387871 -68.470686  0.611644
# 3      24            QC  46.795660 -71.356166 -0.778827
# 4      37            QC  45.510311 -73.570841  0.586588
#
#                             geom                    geometry
# 0           45.537593,-73.597075  POINT (-73.59708 45.53759)
# 1           45.488636,-73.568175  POINT (-73.56817 45.48864)
# 2         48.3878711,-68.4706861  POINT (-68.47069 48.38787)
# 3         46.7956598,-71.3561663  POINT (-71.35617 46.79566)
# 4  45.510310700000005,-73.570841  POINT (-73.57084 45.51031)

# %%
px.set_mapbox_access_token("pk.eyJ1Ijoic2hha2Fzb20iLCJhIjoiY2plMWg1NGFpMXZ5NjJxbjhlM2ttN3AwbiJ9.RtGYHmreKiyBfHuElgYq_w")

# %%
px.scatter_mapbox(gdf, lat="lat", lon="long",size_max=6, zoom=8, width=1000, height=600)
# Out:
# <div>
#
#
#             <div id="76416f0a-0645-42fb-9461-872db692aa54" class="plotly-graph-div" style="height:600px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("76416f0a-0645-42fb-9461-872db692aa54")) {
#                     Plotly.newPlot(
#                         '76416f0a-0645-42fb-9461-872db692aa54',
# ...

# %%
polygon = gpd.read_file("quebec.geojson.txt")

# %%
polygon
# Out:
#                                name  cartodb_id           created_at  \
# 0         Saguenay - Lac-Saint-Jean           2  2013-12-03T20:10:58
# 1   Gaspésie - Îles-de-la-Madeleine           3  2013-12-03T20:10:58
# 2             Abitibi-Témiscamingue           4  2013-12-03T20:10:58
# 3                          Mauricie           5  2013-12-03T20:10:58
# 4                Capitale-Nationale           6  2013-12-03T20:10:58
# 5                         Outaouais           7  2013-12-03T20:10:58
# 6                        Montérégie           8  2013-12-03T20:10:58
# 7                            Estrie           9  2013-12-03T20:10:58
# 8                    Nord-du-Québec          11  2013-12-03T20:10:58
# 9                       Laurentides          14  2013-12-03T20:10:58
# 10                       Lanaudière          15  2013-12-03T20:10:58
# 11             Chaudière-Appalaches          16  2013-12-03T20:10:58
# 12                        Côte-Nord           1  2013-12-03T20:10:58
# ...

# %%
fig, ax = plt.subplots(figsize=(20,10))
gdf.plot(ax=ax, color="black")
polygon.plot(ax=ax)
#plt.tight_layout()
#plt.axis(‘off’)
plt.show()

# %%
import descartes

# %%
polygon
# Out:
#                                name  cartodb_id           created_at  \
# 0         Saguenay - Lac-Saint-Jean           2  2013-12-03T20:10:58
# 1   Gaspésie - Îles-de-la-Madeleine           3  2013-12-03T20:10:58
# 2             Abitibi-Témiscamingue           4  2013-12-03T20:10:58
# 3                          Mauricie           5  2013-12-03T20:10:58
# 4                Capitale-Nationale           6  2013-12-03T20:10:58
# 5                         Outaouais           7  2013-12-03T20:10:58
# 6                        Montérégie           8  2013-12-03T20:10:58
# 7                            Estrie           9  2013-12-03T20:10:58
# 8                    Nord-du-Québec          11  2013-12-03T20:10:58
# 9                       Laurentides          14  2013-12-03T20:10:58
# 10                       Lanaudière          15  2013-12-03T20:10:58
# 11             Chaudière-Appalaches          16  2013-12-03T20:10:58
# 12                        Côte-Nord           1  2013-12-03T20:10:58
# ...

# %%
mask = (polygon.loc[15]["geometry"])
pip_mask_geofence = gdf.within(mask)

# %%
pip_mask_geofence
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 1147    False
# 1148    False
# 1149    False
# 1150    False
# 1151    False
# Length: 1152, dtype: bool

# %%
gdf.loc[:,"geofence"] = pip_mask_geofence
gdf.sample(5)
# Out:
#      erp_id province_code        lat       long     sales  \
# 668    4036            QC  45.534699 -73.569848 -0.207679
# 479    3023            QC  45.542240 -73.589647  0.174559
# 282    1746            QC  46.812856 -71.212283  0.966181
# 199    1286            QC  46.885501 -71.199851 -0.587295
# 19      135            QC  45.500265 -73.574887  0.072579
#
#                                geom                    geometry  geofence
# 668   45.534698999999996,-73.569848  POINT (-73.56985 45.53470)      True
# 479          45.5422402,-73.5896475  POINT (-73.58965 45.54224)      True
# 282          46.8128563,-71.2122832  POINT (-71.21228 46.81286)     False
# 199  46.885501299999994,-71.1998508  POINT (-71.19985 46.88550)     False
# 19            45.500265,-73.5748868  POINT (-73.57489 45.50026)      True

# %%
gdf["geofence"].value_counts()
# Out:
# True     637
# False    515
# Name: geofence, dtype: int64

# %%
px.scatter_mapbox(gdf, lat="lat", lon="long", color="geofence", size="erp_id",
size_max=6, zoom=12, width=1200, height=800)
# Out:
# <div>
#
#
#             <div id="25987a4e-5e0e-47d1-8f63-16a3a88a9a02" class="plotly-graph-div" style="height:800px; width:1200px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("25987a4e-5e0e-47d1-8f63-16a3a88a9a02")) {
#                     Plotly.newPlot(
#                         '25987a4e-5e0e-47d1-8f63-16a3a88a9a02',
# ...

# %%
map1 = folium.Map(
    location=[45.534699,-73.7464738],
    tiles='cartodbpositron',
    zoom_start=12,
)
df.apply(lambda row:folium.CircleMarker(location=[row["lat"], row["long"]]).add_to(map1), axis=1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
import folium
